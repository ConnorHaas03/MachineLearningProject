# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# df = pd.read_csv (r'Path where the CSV file is stored\File name.csv')
# print (df)

# %%
train_e= pd.read_csv('train_edited.csv')
train_e
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LotConfig  \
# 0        1          60       RL         65.0     8450      Reg    Inside
# 1        2          20       RL         80.0     9600      Reg       FR2
# 2        3          60       RL         68.0    11250      IR1    Inside
# 3        4          70       RL         60.0     9550      IR1    Corner
# 4        5          60       RL         84.0    14260      IR1       FR2
# ...    ...         ...      ...          ...      ...      ...       ...
# 1455  1456          60       RL         62.0     7917      Reg    Inside
# 1456  1457          20       RL         85.0    13175      Reg    Inside
# 1457  1458          70       RL         66.0     9042      Reg    Inside
# 1458  1459          20       RL         68.0     9717      Reg    Inside
# 1459  1460          20       RL         75.0     9937      Reg    Inside
#
#      Neighborhood HouseStyle  OverallQual  ...  Foundation  BsmtQual  \
# ...

# %%
# sns.set()
# cols = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
# sns.pairplot(train_e[cols], size = 2.5)
# plt.show();
# plt.savefig('pairplot.png',bbox_inches='tight')

# %%
# categorical features
categorical_feat1 = train_e.columns[train_e.dtypes=='object'].tolist()

# numerical features
numeric_feat1 = train_e.columns[(train_e.dtypes=='int64')|(train_e.dtypes=='float64')]

print('categorical features:\n{}\n{}'.format(sorted(categorical_feat1), len(categorical_feat1)))
print('\nnumerical features:\n{}\n{}'.format(sorted(numeric_feat1), len(numeric_feat1)))
# Out:
# categorical features:
# ['BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation', 'HeatingQC', 'HouseStyle', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType', 'Neighborhood', 'RoofStyle']
# 16
#
# numerical features:
# ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'Id', 'LotArea', 'LotFrontage', 'MSSubClass', 'MasVnrArea', 'OverallCond', 'OverallQual', 'TotalBsmtSF', 'YearBuilt', 'YearRemodAdd']
# 13

# %%
total = train_e.isnull().sum().sort_values(ascending=False)
percent = (train_e.isnull().sum()/train_e.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# LotFrontage     259  0.177397
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrType        8  0.005479
# MasVnrArea        8  0.005479
# LotConfig         0  0.000000
# HouseStyle        0  0.000000
# Neighborhood      0  0.000000
# BsmtFinSF2        0  0.000000
# LotShape          0  0.000000
# OverallCond       0  0.000000
# LotArea           0  0.000000
# MSZoning          0  0.000000
# MSSubClass        0  0.000000
# OverallQual       0  0.000000
# Exterior1st       0  0.000000
# YearBuilt         0  0.000000
# YearRemodAdd      0  0.000000

# %%
train_e.HouseStyle.unique()
# Out:
# array(['2Story', '1Story', '1.5Fin', '1.5Unf', 'SFoyer', 'SLvl', '2.5Unf',
#        '2.5Fin'], dtype=object)

# %%
train_e.MSZoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
HouseStyle_dummy = pd.get_dummies(train_e, columns=['HouseStyle'])
HouseStyle_dummy
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LotConfig  \
# 0        1          60       RL         65.0     8450      Reg    Inside
# 1        2          20       RL         80.0     9600      Reg       FR2
# 2        3          60       RL         68.0    11250      IR1    Inside
# 3        4          70       RL         60.0     9550      IR1    Corner
# 4        5          60       RL         84.0    14260      IR1       FR2
# ...    ...         ...      ...          ...      ...      ...       ...
# 1455  1456          60       RL         62.0     7917      Reg    Inside
# 1456  1457          20       RL         85.0    13175      Reg    Inside
# 1457  1458          70       RL         66.0     9042      Reg    Inside
# 1458  1459          20       RL         68.0     9717      Reg    Inside
# 1459  1460          20       RL         75.0     9937      Reg    Inside
#
#      Neighborhood  OverallQual  OverallCond  ...  TotalBsmtSF  HeatingQC  \
# ...
