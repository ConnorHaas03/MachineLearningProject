# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df2= pd.read_csv('train with adjusted columns.csv')
df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train_e = pd.read_csv('train_edited.csv')
train_e
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LotConfig  \
# 0        1          60       RL         65.0     8450      Reg    Inside
# 1        2          20       RL         80.0     9600      Reg       FR2
# 2        3          60       RL         68.0    11250      IR1    Inside
# 3        4          70       RL         60.0     9550      IR1    Corner
# 4        5          60       RL         84.0    14260      IR1       FR2
# ...    ...         ...      ...          ...      ...      ...       ...
# 1455  1456          60       RL         62.0     7917      Reg    Inside
# 1456  1457          20       RL         85.0    13175      Reg    Inside
# 1457  1458          70       RL         66.0     9042      Reg    Inside
# 1458  1459          20       RL         68.0     9717      Reg    Inside
# 1459  1460          20       RL         75.0     9937      Reg    Inside
#
#      Neighborhood HouseStyle  OverallQual  ...  Foundation  BsmtQual  \
# ...

# %%
train = pd.read_csv('train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test = pd.read_csv('test.csv')

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(train['SalePrice']);

# %%
sns.distplot(train['YrSold']);

# %%
sns.distplot(train['YearBuilt']);

# %%
sns.distplot(train['YearRemodAdd']);

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')

# %%
var = 'LotArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'LotFrontage'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'PoolArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'MiscVal'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'MoSold'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
var = 'LotArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-ground.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'BsmtFinSF2'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-basement.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'BsmtFinSF1'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-basement.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'YearBuilt'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-basement.png',bbox_inches='tight')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
plt.savefig('scatter-basement.png',bbox_inches='tight')

# %%
var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.savefig('boxplot-quality.png',bbox_inches='tight')

# %%
var = 'YrSold'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.savefig('boxplot-quality.png',bbox_inches='tight')

# %%
var = 'OverallCond'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.savefig('boxplot-quality.png',bbox_inches='tight')

# %%
var = 'GarageCars'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.savefig('boxplot-quality.png',bbox_inches='tight')

# %%
#saleprice correlation matrix
corrmat = train.corr()
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.00)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
plt.savefig('heatmap.png',bbox_inches='tight')

# %%
sns.set()
cols = ['SalePrice', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallCond', 'BsmtFinSF1', 'BsmtFinSF2', '1stFlrSF', '2ndFlrSF']
sns.pairplot(train[cols], size = 2.5)
plt.show();
plt.savefig('pairplot.png',bbox_inches='tight')

# %%
# categorical features
categorical_feat1 = train.columns[train.dtypes=='object'].tolist()

# numerical features
numeric_feat1 = train.columns[(train.dtypes=='int64')|(train.dtypes=='float64')].drop('SalePrice').tolist()

print('categorical features:\n{}\n{}'.format(sorted(categorical_feat1), len(categorical_feat1)))
print('\nnumerical features:\n{}\n{}'.format(sorted(numeric_feat1), len(numeric_feat1)))
# Out:
# categorical features:
# ['Alley', 'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Fence', 'FireplaceQu', 'Foundation', 'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour', 'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType', 'MiscFeature', 'Neighborhood', 'PavedDrive', 'PoolQC', 'RoofMatl', 'RoofStyle', 'SaleCondition', 'SaleType', 'Street', 'Utilities']
# 43
#
# numerical features:
# ...

# %%
total = df2.isnull().sum().sort_values(ascending=False)
percent = (df2.isnull().sum()/df2.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# Alley          1369  0.937671
# LotFrontage     259  0.177397
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# BldgType          0  0.000000
# Condition2        0  0.000000
# Condition1        0  0.000000
# Neighborhood      0  0.000000
# LandSlope         0  0.000000
# LotConfig         0  0.000000
# SalePrice         0  0.000000
# Utilities         0  0.000000
# LandContour       0  0.000000
# LotShape          0  0.000000
# OverallQual       0  0.000000

# %%
set(train.select_dtypes(include='int64').columns).symmetric_difference(set(test.select_dtypes('int64')))
# Out:
# {'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtUnfSF',
#  'GarageArea',
#  'GarageCars',
#  'SalePrice',
#  'TotalBsmtSF'}

# %%
df= train.loc[:,'CentralAir':]
df
# Out:
#      CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0             Y      SBrkr       856       854             0       1710
# 1             Y      SBrkr      1262         0             0       1262
# 2             Y      SBrkr       920       866             0       1786
# 3             Y      SBrkr       961       756             0       1717
# 4             Y      SBrkr      1145      1053             0       2198
# ...         ...        ...       ...       ...           ...        ...
# 1455          Y      SBrkr       953       694             0       1647
# 1456          Y      SBrkr      2073         0             0       2073
# 1457          Y      SBrkr      1188      1152             0       2340
# 1458          Y      FuseA      1078         0             0       1078
# 1459          Y      SBrkr      1256         0             0       1256
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  ...  PoolArea  PoolQC  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 43 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
#jae function 
for c in df2.columns[:]:
    if c in ['MSSubClass', 'MSZoning', 'LotFrontage'      
'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour'      
'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',     
'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual'
'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle'
'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
'Heating', 'HeatingQC']:
        print('\nCOLUMN: "{}"\n=============================='.format(c))
        print(df2[c].value_counts(dropna=False).to_string())
        #only include above columns categorical
        continue
#What to Drop: 
#Heating, Very high correlation 
#MSZoning, Heavily weighted, but we could take the percentage, we should transform the data to balance out the material more.
#Drop Street 
#Drop Alley 
#Group LotShape and LotConfig together, or just get rid of LotShape and keep LotConfig  
#Check for correlation between Condition1 and Condition2 and group them together seeing as they are the same thing.
#Compare the YearBuilt Columns to the YearRemodAdd column, to see how they correlate in regards to sales price. 
#Check the correlation between Exterior1st and Exterior2nd, they are almost the exact same thing. 
#Combine to see where MasVnrArea relates to MasVnrType, and see how quality is impacted because of that. 
#Get rid of the ExterCond column 
#Keep BsmtQual, but drop the BsmtCond column, only one is necessary to show what is needed. 
#Test the variance between BsmtExposure and Salesprice to see if "No" adds value to the sales price. 
#Just use the TotalBsmtSF column for basement numerical values.
# Out:
# COLUMN: "MSSubClass"
# ...
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
#
# COLUMN: "MSZoning"
# ...
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
#
# COLUMN: "Street"
# ...
# Pave    1454
# Grvl       6
#
# COLUMN: "Alley"
# ...
# NaN     1369
# Grvl      50
# Pave      41
#
# COLUMN: "LotShape"
# ...
# Reg    925
# IR1    484
# IR2     41
# IR3     10
#
# COLUMN: "LotConfig"
# ...
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
#
# COLUMN: "LandSlope"
# ...
# Gtl    1382
# Mod      65
# Sev      13
#
# COLUMN: "Neighborhood"
# ...
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# ...

# %%
# #jae function 
# for c in df.columns[:]:
#     if c in ['CentralAir', 'Electrical', 'KitchenQual', 
#              'Functional', 'FireplaceQu', 'GarageType',
#              'GarageFinish', 'GarageQual', 'GarageQual',
#              'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']:
#         print('\nCOLUMN: "{}"\n=============================='.format(c))
#         print(df[c].value_counts(dropna=False).to_string())
#         #only include above columns categorical
#         continue
# Out:
# COLUMN: "CentralAir"
# ...
# Y    1365
# N      95
#
# COLUMN: "Electrical"
# ...
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
#
# COLUMN: "KitchenQual"
# ...
# TA    735
# Gd    586
# Ex    100
# Fa     39
#
# COLUMN: "Functional"
# ...
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
#
# COLUMN: "FireplaceQu"
# ...
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
#
# COLUMN: "GarageType"
# ...
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
#
# COLUMN: "GarageFinish"
# ...
# Unf    605
# RFn    422
# Fin    352
# NaN     81
#
# COLUMN: "GarageQual"
# ...
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Po        3
# Ex        3
#
# COLUMN: "PavedDrive"
# ...
# Y    1340
# N      90
# P      30
#
# COLUMN: "PoolQC"
# ...
# NaN    1453
# Gd        3
# Fa        2
# Ex        2
#
# COLUMN: "Fence"
# ...
# NaN      1179
# MnPrv     157
# ...

# %%
df2.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
#Percentage missing per column
(df2.count()/1460)*100
# Out:
# Id               100.000000
# MSSubClass       100.000000
# MSZoning         100.000000
# LotFrontage       82.260274
# LotArea          100.000000
# Street           100.000000
# Alley              6.232877
# LotShape         100.000000
# LandContour      100.000000
# Utilities        100.000000
# LotConfig        100.000000
# LandSlope        100.000000
# Neighborhood     100.000000
# Condition1       100.000000
# Condition2       100.000000
# BldgType         100.000000
# HouseStyle       100.000000
# OverallQual      100.000000
# OverallCond      100.000000
# YearBuilt        100.000000
# YearRemodAdd     100.000000
# RoofStyle        100.000000
# RoofMatl         100.000000
# Exterior1st      100.000000
# Exterior2nd      100.000000
# MasVnrType        99.452055
# MasVnrArea        99.452055
# ExterQual        100.000000
# ExterCond        100.000000
# Foundation       100.000000
# BsmtQual          97.465753
# BsmtCond          97.465753
# BsmtExposure      97.397260
# ...

# %%
sns.set()
#'SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt'
cols = ['SalePrice', 'MSSubClass', 'MSZoning', 'LotConfig', 'YearBuilt', 'YearRemodAdd']
sns.pairplot(df2[cols], size = 2.5)
plt.show();
plt.savefig('pairplot.png',bbox_inches='tight')

# %%
sns.set()
#'SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt'
cols = ['SalePrice', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'TotalBsmtSF']
sns.pairplot(df2[cols], size = 2.5)
plt.show();
plt.savefig('pairplot.png',bbox_inches='tight')

# %%
var = 'MasVnrType'
data = pd.concat([df2['MasVnrArea'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="MasVnrArea", data=data)
fig.axis(ymin=0, ymax=1500);
plt.savefig('boxplot-quality.png',bbox_inches='tight')

# %%
var = 'YearBuilt'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
var = 'YearRemodAdd'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
var = 'BsmtFinType1'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
var = 'BsmtFinType2'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
var = 'SaleCondition'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
var = 'HeatingQC'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.barplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('barplot.png',bbox_inches='tight')

# %%
var = 'HeatingQC'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);
plt.savefig('boxplot.png',bbox_inches='tight')

# %%
#lambda
alphas = np.linspace(0.1,1e4,20)
#target
prices = pd.Series(df2.SalePrice)
#numerical dataframe
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df2 = df.select_dtypes(include=numerics).copy() #81 na in GarageYrBlt
df2.isna().sum() #count nas per col
df2.GarageYrBlt.fillna(0, inplace=True) # replace na with 0 because no data given
#df2 has 25 columns, 10 unique colors for elasticNet
elasticNet(alphas,df2.iloc[:,:24],prices,1) #1 for lasso, 0 for ridge, mixture is elastic net
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-a6d450e93f52> in <module>
#       9 df2.GarageYrBlt.fillna(0, inplace=True) # replace na with 0 because no data given
#      10 #df2 has 25 columns, 10 unique colors for elasticNet
# ---> 11 elasticNet(alphas,df2.iloc[:,:24],prices,1) #1 for lasso, 0 for ridge, mixture is elastic net
#
# NameError: name 'elasticNet' is not defined
