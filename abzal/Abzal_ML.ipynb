# %% [markdown]
# ## Abzal Bacchus-- Random Forest ML Project

# %%
# TODO:  RandomForest for the ML project...clean then push

# https://intellipaat.com/blog/what-is-random-forest-algorithm-in-python/

# https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6

# %%
pip3 install xgboost # why isnt it working?
# Out:
#   File "<ipython-input-31-3debf2381671>", line 1
#     pip3 install xgboost
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Importing all necessary modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import random as rn
import matplotlib.pyplot as plt
import sklearn
from sklearn.feature_selection import chi2
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from scipy import stats
import math as math
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
# from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
# from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
import math
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Import train.csv

# %%
train = pd.read_csv('train.csv', index_col = 'Id')
train
# train = train.drop('Id', axis=0)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# # Defining features:
# - Here, all the columns and rows are included, and the last column "SalePrice" is excluded

# %%
X = pd.DataFrame(train.iloc[:,:-1])
X
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# ...

# %%
chosen = ['LotFrontage','LotArea','LotShape','HouseStyle',
'OverallQual','OverallCond','YearBuilt','YearRemodAdd', 'CentralAir',
'MasVnrArea','1stFlrSF','2ndFlrSF','GrLivArea','Heating','Neighborhood',
'BsmtFullBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr',
'KitchenQual','Fireplaces','GarageType','GarageCars',
'WoodDeckSF','OpenPorchSF','PoolArea']

final = X[chosen].copy() # use final from here on in

# %% [markdown]
# # Handle missingness implementing Connors functions

# %%
#find numeric columns in given df,replace missing rows with column mean, return dataframe
def num_cleaner (df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    cl_df = pd.DataFrame()
    df2 = df.select_dtypes(include=numerics).copy() #only numeric columns
    nullCols = df2.isnull() #df of T/F, T if null (bool mask)
    means = df2.mean() #series of mean per column
    for c in df2:
        for r in range(0,len(df2)-1):
            if df2[c].iloc[r] and nullCols[c].iloc[r]:
                df2[c].iloc[r] = means[c]
              #print(df2[c].iloc[r]) #sanity check, last 8 should be 103.685 for MasVnrArea
    cl_df = df2.copy() #this will return only numeric features, need to add back type ob features after cleaning/dummify them
    return cl_df

new_cleaned_df = num_cleaner(final) # the new cleaned dataframe stored to a new variable 
new_cleaned_df
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1            65.0     8450            7            5       2003          2003
# 2            80.0     9600            6            8       1976          1976
# 3            68.0    11250            7            5       2001          2002
# 4            60.0     9550            7            5       1915          1970
# 5            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1456         62.0     7917            6            5       1999          2000
# 1457         85.0    13175            6            6       1978          1988
# 1458         66.0     9042            7            9       1941          2006
# 1459         68.0     9717            5            6       1950          1996
# 1460         75.0     9937            5            6       1965          1965
#
# ...

# %%
#dummify object columns and return dataframe
def mass_dummify (df):
    df2 = df.select_dtypes(include=object).copy()
    dum_df = pd.get_dummies(df2) #currently 61 columns, no neighborhoods
    return dum_df

output = mass_dummify(final)
# Out:
#       LotShape_IR1  LotShape_IR2  LotShape_IR3  LotShape_Reg  \
# Id
# 1                0             0             0             1
# 2                0             0             0             1
# 3                1             0             0             0
# 4                1             0             0             0
# 5                1             0             0             0
# ...            ...           ...           ...           ...
# 1456             0             0             0             1
# 1457             0             0             0             1
# 1458             0             0             0             1
# 1459             0             0             0             1
# 1460             0             0             0             1
#
#       HouseStyle_1.5Fin  HouseStyle_1.5Unf  HouseStyle_1Story  \
# Id
# 1                     0                  0                  0
# 2                     0                  0                  1
# ...

# %% [markdown]
# ## Here in one cell the two functions num_clean and ob_clean are being called and concatenated into a newly created df, named cl_df

# %%
# num clean + mass dummify in one cell here:
num_clean = num_cleaner(final).copy()
#cleaned
ob_clean = mass_dummify(final).copy()
#print(ob_clean.count())
#combine num & ob dataset
cl_df = pd.concat([num_clean,ob_clean],axis=1)
cl_df # run randomforest on this!!!!
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1            65.0     8450            7            5       2003          2003
# 2            80.0     9600            6            8       1976          1976
# 3            68.0    11250            7            5       2001          2002
# 4            60.0     9550            7            5       1915          1970
# 5            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# ...

# %% [markdown]
# # Defining the target y
# -The "SalePrice" column (target)

# %%
y = pd.DataFrame(train.iloc[:, -1])
y
# Out:
#       SalePrice
# Id
# 1        208500
# 2        181500
# 3        223500
# 4        140000
# 5        250000
# ...         ...
# 1456     175000
# 1457     210000
# 1458     266500
# 1459     142125
# 1460     147500
#
# [1460 rows x 1 columns]

# %% [markdown]
# # Here, a train_test_split is implemented:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cl_df, y, test_size  = 0.30) # here I'm doing a 70/30 split but feel free to change

# %%
X_train
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 46      61.000000     7658            9            5       2005          2005
# 471     70.049958     6820            8            5       1985          1985
# 1068    80.000000     9760            6            6       1964          1964
# 496     60.000000     7879            4            5       1920          1950
# 478    105.000000    13693            9            5       2006          2006
# ...           ...      ...          ...          ...        ...           ...
# 312     50.000000     8000            6            6       1948          2002
# 847     75.000000     9317            7            5       1993          1993
# 423    100.000000    21750            5            5       1954          1954
# 67      70.049958    19900            7            5       1970          1989
# 1075    74.000000     8556            7            5       2006          2006
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor 

regressor = RandomForestRegressor(n_estimators = 20, random_state = 0) # feel free to alter these parameters 
regressor.fit(X_train, y_train)
y_prediction = regressor.predict(cl_df) # apply the prediction to the whole dataframe; namely cl_df 
y_prediction = np.delete(y_prediction, (-1), axis = 0) # remove last row
y_prediction.size
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 1459

# %%
y_prediction
# Out:
# array([208830.75      , 441332.3       , 172627.5       , 199552.4       ,
#        133284.2       , 127797.5       , 276185.        , 194832.5       ,
#        320273.05      , 596793.3       , 260232.5       , 160199.5       ,
#        227369.2       , 128330.4       , 220511.4       , 118890.        ,
#        348255.55      , 185103.5       , 156692.5       , 250665.65      ,
#        120795.        , 258035.75      , 139376.75      , 147558.7       ,
#        263794.        , 167860.        , 157775.        , 170971.1       ,
#        104315.        , 143300.        , 231912.8       , 148987.95      ,
#        118150.        ,  64997.5       , 174451.5       , 149542.5       ,
#        161477.5       , 172844.5       ,  74450.        , 186064.        ,
#         82800.        , 373067.15      , 121146.7       , 326828.05      ,
#        130362.5       , 156980.        , 224621.2       , 162295.        ,
# ...

# %%
print('Mean error: %.2f' % mean_absolute_error(y_test, y_prediction))
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_prediction))
print('RMSE: %.4f'  % np.sqrt(mean_squared_error(y_test, y_prediction)))
print('R squared for train: %.4f'  % regressor.score(X_train,y_train))
print('R squared for test: %.4f'  % regressor.score(X_test,y_test))
# Out:
# Mean error: 18619.36
# Mean squared error: 854129322.44
# RMSE: 29225.4910
# R squared for train: 0.9666
# R squared for test: 0.8757

# %%
# export predict as csv and then on to kaggle to see:

prediction_df = pd.DataFrame()
prediction_df['Id'] = range(1461, 2920) # new Id column

prediction = y_prediction.round(0).astype(int)
prediction_df['SalePrice'] = prediction # make a new column named SalePrice 
prediction_df.to_csv('./prediction_output.csv') # name of output file, contains Id + SalePrice

# %%
# code snippet pulled from online might be helpful

rf = RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=19,
                      max_features=23, max_leaf_nodes=None,
                      min_impurity_decrease=1e-06, min_impurity_split=None,
                      min_samples_leaf=3, min_samples_split=2,
                      min_weight_fraction_leaf=0.0001, n_estimators=58,
                      n_jobs=None, oob_score=False, random_state=108, verbose=0, # change the random_state to any#
                      warm_start=False)

print(rf)
rf.fit(X_train,y_train)
print(get_error(X_train, y_train, X_test, y_test, rf))
mean_squared_error(y_test, rf.predict(X_test))
